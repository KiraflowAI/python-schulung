# %%
def sag_hallo():
    print('Moin')

sag_hallo()
# Out:
# Moin

# %%
77 + 88
# Out:
# 165

# %%
sag_hallo()
# Out:
# Moin

# %%
a = 100

# %%
print(a)
# Out:
# 100

# %%
import pandas as pd

# %%
pd.read_csv('bookstore.csv')
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df = pd.read_csv('bookstore.csv')

# %%
df
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df.head(5)
# Out:
#                               Title                       Author  \
# 0             The Lord of the Rings              Tolkien, J.R.R.
# 1                         The Bible  International Bible Society
# 2          The Pillars of the Earth                 Follett, Ken
# 3  Perfume: The Story of a Murderer             Süskind, Patrick
# 4                 The Little Prince    Saint-Exupéry, Antoine de
#
#    Publication Year  List Price  Sale Price  Condition
# 0              1992        7.99        2.69   like new
# 1              2003        7.50        2.49   like new
# 2              2002       19.95        1.49  very good
# 3              2003       19.95        1.29  very good
# 4              2006       24.95        2.59       good

# %%
df.tail(5)
# Out:
#                      Title                  Author  Publication Year  \
# 25   The Neverending Story           Ende, Michael              1978
# 26         The Hidden Word              Hahn, Ulla              2000
# 27          Angela’s Ashes          McCourt, Frank              2003
# 28  Narcissus and Goldmund          Hesse, Hermann              2004
# 29     The Mists of Avalon  Zimmer Bradley, Marion              2000
#
#     List Price  Sale Price  Condition
# 25       26.95        1.49  very good
# 26        6.99        1.29   like new
# 27       24.95        1.29  very good
# 28        6.99        1.29   like new
# 29        5.99        1.29  very good

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape # Zeilenanzahl, Spaltenanzahl
# Out:
# (30, 6)

# %%
df.columns # überschrift
# Out:
# Index(['Title', 'Author', 'Publication Year', 'List Price', 'Sale Price',
#        'Condition'],
#       dtype='object')

# %%
df.index # Wie bei range, index wird ausgegeben
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
df.pad
# Out:
# <bound method NDFrame.pad of                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df.loc[3]
# Out:
# Title               Perfume: The Story of a Murderer
# Author                              Süskind, Patrick
# Publication Year                                2003
# List Price                                     19.95
# Sale Price                                      1.29
# Condition                                  very good
# Name: 3, dtype: object

# %%
df.loc[0]
# Out:
# Title               The Lord of the Rings
# Author                    Tolkien, J.R.R.
# Publication Year                     1992
# List Price                           7.99
# Sale Price                           2.69
# Condition                        like new
# Name: 0, dtype: object

# %%
df.loc[1:3] # bis einschließlich 3
# Out:
#                               Title                       Author  \
# 1                         The Bible  International Bible Society
# 2          The Pillars of the Earth                 Follett, Ken
# 3  Perfume: The Story of a Murderer             Süskind, Patrick
#
#    Publication Year  List Price  Sale Price  Condition
# 1              2003        7.50        2.49   like new
# 2              2002       19.95        1.49  very good
# 3              2003       19.95        1.29  very good

# %%
df.loc[10:20:2]
# Out:
#                                         Title                       Author  \
# 10                                   Inkheart              Funke, Cornelia
# 12                   The House of the Spirits              Allende, Isabel
# 14                                      Faust  Goethe, Johann Wolfgang von
# 16                        Pride and Prejudice                 Austen, Jane
# 18                            Angels & Demons                   Brown, Dan
# 20  Harry Potter and the Order of the Phoenix                Rowling, J.K.
#
#     Publication Year  List Price  Sale Price  Condition
# 10              2005        9.99        0.99   like new
# 12              2003        7.99        1.49  very good
# 14              2005        7.50        2.49  very good
# 16              2006        6.99        1.29   like new
# 18              1998        5.95        1.29   like new
# 20              1995        7.99        1.99  very good

# %%
df.loc[10:15]
# Out:
#                        Title                       Author  Publication Year  \
# 10                  Inkheart              Funke, Cornelia              2005
# 11                 Outlander              Gabaldon, Diana              1987
# 12  The House of the Spirits              Allende, Isabel              2003
# 13                The Reader            Schlink, Bernhard              1996
# 14                     Faust  Goethe, Johann Wolfgang von              2005
# 15    The Shadow of the Wind           Ruiz Zafón, Carlos              1998
#
#     List Price  Sale Price  Condition
# 10        9.99        0.99   like new
# 11        6.99        1.29  very good
# 12        7.99        1.49  very good
# 13        6.99        1.29  very good
# 14        7.50        2.49  very good
# 15        5.99        1.29  very good

# %%
df.loc[1] # wird als series zurück gegben als eine spalte
# Out:
# Title                                 The Bible
# Author              International Bible Society
# Publication Year                           2003
# List Price                                  7.5
# Sale Price                                 2.49
# Condition                              like new
# Name: 1, dtype: object

# %%
type(df.loc[1])
# Out:
# pandas.core.series.Series

# %%
df.loc[1:1] #hier in tabellenform
# Out:
#        Title                       Author  Publication Year  List Price  \
# 1  The Bible  International Bible Society              2003         7.5
#
#    Sale Price Condition
# 1        2.49  like new

# %%
df.loc[3:8, 'Title']
# Out:
# 3         Perfume: The Story of a Murderer
# 4                        The Little Prince
# 5                             Buddenbrooks
# 6                            The Physician
# 7                            The Alchemist
# 8    Harry Potter and the Sorcerer’s Stone
# Name: Title, dtype: object

# %%
df.loc[3:8, ['Title', 'List Price']]
# Out:
#                                    Title  List Price
# 3       Perfume: The Story of a Murderer       19.95
# 4                      The Little Prince       24.95
# 5                           Buddenbrooks        7.99
# 6                          The Physician       25.95
# 7                          The Alchemist        7.50
# 8  Harry Potter and the Sorcerer’s Stone        7.99

# %%
df.loc[:, 'Title'] #von anfang bis ende von der spalte titel
# Out:
# 0                         The Lord of the Rings
# 1                                     The Bible
# 2                      The Pillars of the Earth
# 3              Perfume: The Story of a Murderer
# 4                             The Little Prince
# 5                                  Buddenbrooks
# 6                                 The Physician
# 7                                 The Alchemist
# 8         Harry Potter and the Sorcerer’s Stone
# 9                                     Pope Joan
# 10                                     Inkheart
# 11                                    Outlander
# 12                     The House of the Spirits
# 13                                   The Reader
# 14                                        Faust
# 15                       The Shadow of the Wind
# 16                          Pride and Prejudice
# 17                         The Name of the Rose
# 18                              Angels & Demons
# 19                                  Effi Briest
# ...

# %%
df.iloc[0:4, [0,2]] # iloc ist die integer location  , 4 ist exclusive, o te spalte mit spalte 2
# Out:
#                               Title  Publication Year
# 0             The Lord of the Rings              1992
# 1                         The Bible              2003
# 2          The Pillars of the Earth              2002
# 3  Perfume: The Story of a Murderer              2003

# %%
df.loc[0, 'Title'] = 'Kira Rules'

# %%
df
# Out:
#                                         Title                       Author  \
# 0                                  Kira Rules              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df.loc[3:15, 'Publication Year'] = 1500

# %%
df
# Out:
#                                         Title                       Author  \
# 0                                  Kira Rules              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df.loc[:, 'gelesen'] = False

# %%
df
# Out:
#                                         Title                       Author  \
# 0                                  Kira Rules              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df.loc[:, 'Doppelter Preis'] = df.loc[:, 'List Price'] * 2

# %%
df
# Out:
#                                         Title                       Author  \
# 0                                  Kira Rules              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...
