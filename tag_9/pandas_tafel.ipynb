# %%
import pandas as pd

# %%
df = pd.read_csv('bookstore.csv')

# %% [markdown]
# '../tag_8/bookstore.csv . Hier kann man als Datenpfad auch den tag 8 nehemen oder etwas anderes, wenn die datei woanders liegt mit .. ist der ordner darüber gemeint.

# %%
df['List Price'].min()
# Out:
# np.float64(5.95)

# %%
df['List Price'].max()
# Out:
# np.float64(26.95)

# %%
df['List Price'].std() # Standardabweichung
# Out:
# np.float64(7.406566021435646)

# %%
df['List Price'].mean() # durchschnittspreis

# %%
df['List Price'].describe()
# Out:
# count    30.000000
# mean     11.679333
# std       7.406566
# min       5.950000
# 25%       6.990000
# 50%       7.990000
# 75%      17.460000
# max      26.950000
# Name: List Price, dtype: float64

# %%
df.max()
# Out:
# Title               The Shadow of the Wind
# Author              Zimmer Bradley, Marion
# Publication Year                      2006
# List Price                           26.95
# Sale Price                            2.69
# Condition                        very good
# dtype: object

# %%
df['Condition'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      like new
# 1      like new
# 2     very good
# 3     very good
# 4          good
# 5     very good
# 6      like new
# 7      like new
# 8     very good
# 9      like new
# 10     like new
# 11    very good
# 12    very good
# 13    very good
# 14    very good
# 15    very good
# 16     like new
# 17    very good
# 18     like new
# 19    very good
# 20    very good
# 21         good
# 22     like new
# 23         good
# 24    very good
# 25    very good
# 26     like new
# 27    very good
# 28     like new
# 29    very good
# Name: Condition, dtype: object>

# %%
df['Condition'].unique() # wie viel verschiedene bezeichnungen gibt es
# Out:
# array(['like new', 'very good', 'good'], dtype=object)

# %%
df['List Price'].unique()
# Out:
# array([ 7.99,  7.5 , 19.95, 24.95, 25.95,  9.99,  6.99,  5.99,  5.95,
#         6.5 , 26.95])

# %%
df['Condition'].value_counts(()) # wie oft sind diese wörter in der gesamten liste
# Out:
# Condition
# very good    16
# like new     11
# good          3
# Name: count, dtype: int64

# %%
df0 = pd.DataFrame([[1,2], [3,4], [5,6]], columns=['Kinder', 'Schuhe'], index=['Reichert', 'Rohlfsen', 'Gelhorn'])
df0 # hier werden zeilenweise die inhalte angegeben
# Out:
#           Kinder  Schuhe
# Reichert       1       2
# Rohlfsen       3       4
# Gelhorn        5       6

# %%
df1 = pd.DataFrame({
    'Autor': df['Author'], 
    'Preis':df['List Price'], 
    'Doppelter Preis': df['List Price']*2
    })
# hier wird spaltenweise inhalte gegeben
df1
# Out:
#                           Autor  Preis  Doppelter Preis
# 0               Tolkien, J.R.R.   7.99            15.98
# 1   International Bible Society   7.50            15.00
# 2                  Follett, Ken  19.95            39.90
# 3              Süskind, Patrick  19.95            39.90
# 4     Saint-Exupéry, Antoine de  24.95            49.90
# 5                  Mann, Thomas   7.99            15.98
# 6                  Gordon, Noah  25.95            51.90
# 7                 Coelho, Paulo   7.50            15.00
# 8                 Rowling, J.K.   7.99            15.98
# 9               Cross, Donna W.  24.95            49.90
# 10              Funke, Cornelia   9.99            19.98
# 11              Gabaldon, Diana   6.99            13.98
# 12              Allende, Isabel   7.99            15.98
# 13            Schlink, Bernhard   6.99            13.98
# 14  Goethe, Johann Wolfgang von   7.50            15.00
# 15           Ruiz Zafón, Carlos   5.99            11.98
# ...

# %%
df1.to_excel('my_bookstore_infomration.xlsx')

# %%
df.sort_values(by='Publication Year', ascending = True) # true für aufsteigend, false für absteigend
# die liste wird hier so bnicht gespeichert sondern angezeigt um es so zu speichern muss man die liste eine neue variable geben z.b. sortiert = df.sortvalues
# Out:
#                                         Title                       Author  \
# 25                      The Neverending Story                Ende, Michael
# 11                                  Outlander              Gabaldon, Diana
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 24                    The Discovery of Heaven               Mulisch, Harry
# 20  Harry Potter and the Order of the Phoenix                Rowling, J.K.
# 13                                 The Reader            Schlink, Bernhard
# 18                            Angels & Demons                   Brown, Dan
# 15                     The Shadow of the Wind           Ruiz Zafón, Carlos
# 7                               The Alchemist                Coelho, Paulo
# 26                            The Hidden Word                   Hahn, Ulla
# 29                        The Mists of Avalon       Zimmer Bradley, Marion
# ...

# %%
df.sort_values(by='Publication Year', ascending=True).reset_index(drop=True)
# Out:
#                                         Title                       Author  \
# 0                       The Neverending Story                Ende, Michael
# 1                                   Outlander              Gabaldon, Diana
# 2                       The Lord of the Rings              Tolkien, J.R.R.
# 3                     The Discovery of Heaven               Mulisch, Harry
# 4   Harry Potter and the Order of the Phoenix                Rowling, J.K.
# 5                                  The Reader            Schlink, Bernhard
# 6                             Angels & Demons                   Brown, Dan
# 7                      The Shadow of the Wind           Ruiz Zafón, Carlos
# 8                               The Alchemist                Coelho, Paulo
# 9                             The Hidden Word                   Hahn, Ulla
# 10                        The Mists of Avalon       Zimmer Bradley, Marion
# ...

# %%
#datentypen

# %%
df.info() # wie viel spalten haben wir, wie heißen diese, welcher datentyp ist gespeichert
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             30 non-null     object
#  1   Author            30 non-null     object
#  2   Publication Year  30 non-null     int64
#  3   List Price        30 non-null     float64
#  4   Sale Price        30 non-null     float64
#  5   Condition         30 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
df
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
# datentyp ändern
df['Publication Year'] = df['Publication Year'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             30 non-null     object
#  1   Author            30 non-null     object
#  2   Publication Year  30 non-null     float64
#  3   List Price        30 non-null     float64
#  4   Sale Price        30 non-null     float64
#  5   Condition         30 non-null     object
# dtypes: float64(3), object(3)
# memory usage: 1.5+ KB

# %%
df
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df['Condition'] = df['Condition'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             30 non-null     object
#  1   Author            30 non-null     object
#  2   Publication Year  30 non-null     float64
#  3   List Price        30 non-null     float64
#  4   Sale Price        30 non-null     float64
#  5   Condition         30 non-null     category
# dtypes: category(1), float64(3), object(2)
# memory usage: 1.5+ KB

# %%
df['Condition'] = df['Condition'].astype('category')

# %%
df.sort_values(by='Condition')
# Out:
#                                         Title                       Author  \
# 21                         The Magic Mountain                 Mann, Thomas
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 23                                 Siddhartha               Hesse, Hermann
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 16                        Pride and Prejudice                 Austen, Jane
# 28                     Narcissus and Goldmund               Hesse, Hermann
# 22                         Gone with the Wind           Mitchell, Margaret
# 10                                   Inkheart              Funke, Cornelia
# 9                                   Pope Joan              Cross, Donna W.
# 7                               The Alchemist                Coelho, Paulo
# 6                               The Physician                 Gordon, Noah
# ...

# %%
df
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
# information die man nicht mehr braucht
df.drop('Sale Price', axis=1)
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
#zeile 1 wird gelöscht
df.drop(1, axis=0)
#df=df.drop zum speichern, bzw. überschreiben
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# 11                                  Outlander              Gabaldon, Diana
# ...

# %%
df
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df.drop_duplicates() # duplicate werden gelöscht
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
df = pd.DataFrame({'Name': ['John', 'Alice', 'Bob', 'John'],
                   'Alter': [28, 25, 22, 35],
                   'Stadt': ['Berlin', 'Hamburg', 'Hamburg', 'München']})
df
# Out:
#     Name  Alter    Stadt
# 0   John     28   Berlin
# 1  Alice     25  Hamburg
# 2    Bob     22  Hamburg
# 3   John     35  München

# %% [markdown]
# FILTERN

# %%
df['Alter']
# Out:
# 0    28
# 1    25
# 2    22
# 3    35
# Name: Alter, dtype: int64

# %%
df[[True, False, True, False]] #jede zweite zweile
# Out:
#    Name  Alter    Stadt
# 0  John     28   Berlin
# 2   Bob     22  Hamburg

# %%
df[[True, False, False, True]]
# Out:
#    Name  Alter    Stadt
# 0  John     28   Berlin
# 3  John     35  München

# %%
df[[False, False, True, False]] # BOOLISCHE MASKE
df[mask]
# Out:
#   Name  Alter    Stadt
# 2  Bob     22  Hamburg

# %%
# alle die in hh wohnen
df['Stadt'] == 'Hamburg' # hier wurde eine boolische maske erzeugt
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: Stadt, dtype: bool

# %%
df[df['Stadt'] == 'Hamburg'] # diese boolische maske wird hier eingetragen in df damit diese ausgegeben werden
# Out:
#     Name  Alter    Stadt
# 1  Alice     25  Hamburg
# 2    Bob     22  Hamburg

# %%
df[df['Alter']>30]
# Out:
#    Name  Alter    Stadt
# 3  John     35  München

# %%
df_books = pd.read_csv('bookstore.csv')
df_books['Sale Price'].min()
# Was ist der günstigster Preis
# Out:
# np.float64(0.99)

# %%
smallest_price = df_books['Sale Price'].min()

# %%
df_books['Sale Price'].min() == df_books['Sale Price']
# Welche Zeilen haben den günstigsten Preis
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: Sale Price, dtype: bool

# %%
mask_smallest_price = smallest_price == df_books['Sale Price']

# %%
df_books[mask_smallest_price]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df_books[mask_smallest_price]
#
# NameError: name 'mask_smallest_price' is not defined

# %%
df_books
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
# durchschnittspreis von jeweiligen zustand
df_books[['Condition', 'Sale Price', 'List Price']].groupby('Condition').mean() # mean ist durchschnitt
# Out:
#            Sale Price  List Price
# Condition
# good         2.123333   13.310000
# like new     1.471818   10.663636
# very good    1.577500   12.071875

# %%
df_books[['Condition', 'Sale Price', 'List Price']].groupby('Condition').max()
# Out:
#            Sale Price  List Price
# Condition
# good             2.59       24.95
# like new         2.69       25.95
# very good        2.49       26.95

# %%
pd.crosstab(index=df_books['Publication Year'], columns=df_books['Condition'])
# Out:
# Condition         good  like new  very good
# Publication Year
# 1978                 0         0          1
# 1987                 0         0          1
# 1992                 0         1          0
# 1994                 0         0          1
# 1995                 0         0          1
# 1996                 0         0          1
# 1998                 0         1          1
# 1999                 0         1          0
# 2000                 0         1          1
# 2001                 0         0          2
# 2002                 0         0          1
# 2003                 0         3          3
# 2004                 1         1          0
# 2005                 1         1          1
# 2006                 1         2          2

# %%
pd.crosstab(index=df_books['Publication Year'], columns=df_books['Condition'], values=df_books['Sale Price'], aggfunc='sum')
# Out:
# Condition         good  like new  very good
# Publication Year
# 1978               NaN       NaN       1.49
# 1987               NaN       NaN       1.29
# 1992               NaN      2.69        NaN
# 1994               NaN       NaN       1.29
# 1995               NaN       NaN       1.99
# 1996               NaN       NaN       1.29
# 1998               NaN      1.29       1.29
# 1999               NaN      1.29        NaN
# 2000               NaN      1.29       1.29
# 2001               NaN       NaN       3.48
# 2002               NaN       NaN       1.49
# 2003               NaN      4.77       4.07
# 2004              1.79      1.29        NaN
# 2005              1.99      0.99       2.49
# 2006              2.59      2.58       3.78

# %%
# neue inhalte / funktion erzeugen
#bsp neues buch oder alt bezogen auf publiocation year

def zeit(year):
    if year < 1990:
        return 'sehr alt'
    if year < 2000:
        return 'alt'
    if year < 2025:
        return 'neu'
    return 'noch nicht erschienen'

df_books['Publication Year'].apply(zeit)
# Out:
# 0          alt
# 1          neu
# 2          neu
# 3          neu
# 4          neu
# 5          neu
# 6          neu
# 7          alt
# 8          neu
# 9          neu
# 10         neu
# 11    sehr alt
# 12         neu
# 13         alt
# 14         neu
# 15         alt
# 16         neu
# 17         neu
# 18         alt
# 19         neu
# 20         alt
# 21         neu
# 22         neu
# 23         neu
# 24         alt
# 25    sehr alt
# 26         neu
# 27         neu
# 28         neu
# 29         neu
# Name: Publication Year, dtype: object

# %%
def zeit(year):
    if year < 1990:
        return 'sehr alt'
    if year < 2000:
        return 'alt'
    if year < 2025:
        return 'neu'
    return 'noch nicht erschienen'

df_books['zeit'] = df_books['Publication Year'].apply(zeit)
df_books
# Out:
#                                         Title                       Author  \
# 0                       The Lord of the Rings              Tolkien, J.R.R.
# 1                                   The Bible  International Bible Society
# 2                    The Pillars of the Earth                 Follett, Ken
# 3            Perfume: The Story of a Murderer             Süskind, Patrick
# 4                           The Little Prince    Saint-Exupéry, Antoine de
# 5                                Buddenbrooks                 Mann, Thomas
# 6                               The Physician                 Gordon, Noah
# 7                               The Alchemist                Coelho, Paulo
# 8       Harry Potter and the Sorcerer’s Stone                Rowling, J.K.
# 9                                   Pope Joan              Cross, Donna W.
# 10                                   Inkheart              Funke, Cornelia
# ...

# %%
import matplotlip as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 import matplotlip as plt
#
# ModuleNotFoundError: No module named 'matplotlip'

# %%
# plots erstellemn 

df_books['Publication Year'].plot(kind='bar')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
df_books['Publication Year'].plot()
# Out:
# <Axes: >

# %%
df_books['Sale Price'].plot(kind='bar')
# Out:
# <Axes: >
